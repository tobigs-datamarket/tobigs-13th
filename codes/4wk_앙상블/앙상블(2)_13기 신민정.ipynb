# %% [markdown]
# # Assignment 2. 캐글 경진대회 참여
# https://www.kaggle.com/c/house-prices-advanced-regression-techniques

# %%
#import some necessary librairies

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline
import matplotlib.pyplot as plt  # Matlab-style plotting
import seaborn as sns
color = sns.color_palette()
sns.set_style('darkgrid')
import warnings
def ignore_warn(*args, **kwargs):
    pass
warnings.warn = ignore_warn #ignore annoying warning (from sklearn and seaborn)


from scipy import stats
from scipy.stats import norm, skew

# %%
test = pd.read_csv('test_new.csv') 
train = pd.read_csv('train_new.csv')

# %%
train
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0      1          60       RL         65.0     8450   Pave   NaN      Reg
# 1      2          20       RL         80.0     9600   Pave   NaN      Reg
# 2      3          60       RL         68.0    11250   Pave   NaN      IR1
# 3      4          70       RL         60.0     9550   Pave   NaN      IR1
# 4      5          60       RL         84.0    14260   Pave   NaN      IR1
# ..   ...         ...      ...          ...      ...    ...   ...      ...
# 855  856          20       RL          NaN     6897   Pave   NaN      IR1
# 856  857          80       RL          NaN    10970   Pave   NaN      IR1
# 857  858          60       RL         65.0     8125   Pave   NaN      Reg
# 858  859          20       RL         80.0    10400   Pave   NaN      Reg
# 859  860          60       RL          NaN    11029   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4           Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ..          ...       ...  ...      ...    ...    ...         ...     ...
# 855         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 856         Low    AllPub  ...        0    NaN  MnPrv         NaN       0
# 857         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 858         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 859         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 0        2   2008        WD         Normal  12.247699
# 1        5   2007        WD         Normal  12.109016
# 2        9   2008        WD         Normal  12.317171
# 3        2   2006        WD        Abnorml  11.849405
# 4       12   2008        WD         Normal  12.429220
# ..     ...    ...       ...            ...        ...
# 855      4   2010        WD         Normal  11.751950
# 856     10   2008        WD         Normal  11.898195
# 857      3   2009        WD         Normal  12.066816
# 858      6   2009        WD         Family  11.931642
# 859      8   2006        WD         Normal  12.429220
#
# [860 rows x 81 columns]

# %%
test
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     861          50       RL         55.0     7642   Pave   NaN      Reg
# 1     862         190       RL         75.0    11625   Pave   NaN      Reg
# 2     863          20       RL         81.0     9672   Pave   NaN      Reg
# 3     864          20       RL         70.0     7931   Pave   NaN      Reg
# 4     865          20       FV         72.0     8640   Pave   NaN      Reg
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 595  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 596  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 597  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 598  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 599  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#     LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# 1           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 2           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# 3           Lvl    AllPub  ...           0        0    NaN  GdPrv         NaN
# 4           Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# ..          ...       ...  ...         ...      ...    ...    ...         ...
# 595         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 596         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 597         Lvl    AllPub  ...           0        0    NaN  GdPrv        Shed
# 598         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 599         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
#
#     MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         0      6    2007        WD         Normal
# 1         0      4    2010        WD         Normal
# 2         0      5    2010        WD         Normal
# 3         0      7    2009        WD         Normal
# 4         0      5    2008       New        Partial
# ..      ...    ...     ...       ...            ...
# 595       0      8    2007        WD         Normal
# 596       0      2    2010        WD         Normal
# 597    2500      5    2010        WD         Normal
# 598       0      4    2010        WD         Normal
# 599       0      6    2008        WD         Normal
#
# [600 rows x 80 columns]

# %%
#check the numbers of samples and features
print("The train data size before dropping Id feature is : {} ".format(train.shape))
print("The test data size before dropping Id feature is : {} ".format(test.shape))

#Save the 'Id' column
train_ID = train['Id']
test_ID = test['Id']

#Now drop the  'Id' colum since it's unnecessary for  the prediction process.
train.drop("Id", axis = 1, inplace = True)
test.drop("Id", axis = 1, inplace = True)

#check again the data size after dropping the 'Id' variable
print("\nThe train data size after dropping Id feature is : {} ".format(train.shape)) 
print("The test data size after dropping Id feature is : {} ".format(test.shape))
# Out:
# The train data size before dropping Id feature is : (860, 81)
# The test data size before dropping Id feature is : (600, 80)
#
# The train data size after dropping Id feature is : (860, 80)
# The test data size after dropping Id feature is : (600, 79)

# %% [markdown]
# # <span style="color:blue"> Data Processing 전처리 같이 해봅시다

# %%
fig, ax = plt.subplots()
ax.scatter(x = train['GrLivArea'], y = train['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %% [markdown]
# **Q1. 위 그림에서 이상치로 판단되는 데이터를 제거하시오.**
#
# **사람마다 기준은 다르나 저는 오른쪽 따로노는 아이가 이상하군요....?**

# %%
#Deleting outliers
train = train.drop(train[(train['GrLivArea']>4000) & (train['SalePrice']<12.5)].index)


#Check the graphic again
fig, ax = plt.subplots()
ax.scatter(train['GrLivArea'], train['SalePrice'])
plt.ylabel('SalePrice', fontsize=13)
plt.xlabel('GrLivArea', fontsize=13)
plt.show()

# %% [markdown]
# 문제 조건에 맞게 오른쪽에 떨어져있는 하나의 값만 drop

# %% [markdown]
# ## Features engineering

# %%
ntrain = train.shape[0]
ntest = test.shape[0]
y_train = train.SalePrice.values
all_data = pd.concat((train, test)).reset_index(drop=True)
all_data.drop(['SalePrice'], axis=1, inplace=True)
print("all_data size is : {}".format(all_data.shape))
# Out:
# all_data size is : (1459, 79)

# %% [markdown]
# ### Missing Data

# %%
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head(20)
# Out:
#               Missing Ratio
# PoolQC            99.520219
# MiscFeature       96.298835
# Alley             93.762851
# Fence             80.740233
# FireplaceQu       47.292666
# LotFrontage       17.751885
# GarageYrBlt        5.551748
# GarageType         5.551748
# GarageQual         5.551748
# GarageFinish       5.551748
# GarageCond         5.551748
# BsmtFinType2       2.604524
# BsmtExposure       2.604524
# BsmtQual           2.535984
# BsmtFinType1       2.535984
# BsmtCond           2.535984
# MasVnrArea         0.548321
# MasVnrType         0.548321
# Electrical         0.068540

# %%
f, ax = plt.subplots(figsize=(15, 12))
plt.xticks(rotation='90')
sns.barplot(x=all_data_na.index, y=all_data_na)
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of missing values', fontsize=15)
plt.title('Percent missing data by feature', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Percent missing data by feature')

# %% [markdown]
# **Data Correlation**

# %%
#Correlation map to see how features are correlated with SalePrice
corrmat = train.corr()
plt.subplots(figsize=(12,9))
sns.heatmap(corrmat, vmax=0.9, square=True)

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# **Q3.결측치를 None으로 바꿔봅시다**
# **그냥 바꾸지만 마시고 왜 None으로 바꾸는지 한번 생각해보세요**

# %% [markdown]
# - **PoolQC** : data description says NA means "No  Pool". That make sense, given the huge ratio of missing value (+99%) and majority of houses have no Pool at all in general.

# %%
all_data["PoolQC"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 1454    NaN
# 1455    NaN
# 1456    NaN
# 1457    NaN
# 1458    NaN
# Name: PoolQC, Length: 1459, dtype: object>

# %%
all_data["PoolQC"] = all_data["PoolQC"].fillna("None")

# %% [markdown]
# - **MiscFeature** : data description says NA means "no misc feature"

# %%
sns.countplot(x="MiscFeature", data=all_data)
plt.title("MiscFeature ")
plt.show()

# %%
all_data["MiscFeature"] = all_data["MiscFeature"].fillna("None")

# %% [markdown]
# None의 의미가  'misc feature없음'이므로 결측치이다.

# %% [markdown]
# - **Alley** : data description says NA means "no alley access"

# %%
all_data["Alley"] = all_data["Alley"].fillna("None")

# %% [markdown]
# - **Fence** : data description says NA means "no fence"

# %%
all_data["Fence"] = all_data["Fence"].fillna("None")

# %% [markdown]
# - **FireplaceQu** : data description says NA means "no fireplace"

# %%
all_data["FireplaceQu"] = all_data["FireplaceQu"].fillna("None")

# %% [markdown]
# **A3. 위의 data의 결측치를 모두 None으로 치환
# 결측치를 한번에 처리하기 위하여 None으로 통일하였습니다.**

# %% [markdown]
# - **LotFrontage** :

# %% [markdown]
#  **Q4. the area of each street connected to the house property most likely have a similar area to other houses in its neighborhood. 인 변수입니다. 그러면 결측치를 어떻게 바꾸는게 좋을까요?**

# %%
all_data["LotFrontage"] = all_data.groupby("Neighborhood")["LotFrontage"].transform(
    lambda x: x.mean())

# %% [markdown]
# Transformation : 그룹 별 계산을 수행하고 생성된 객체를 반환
#
# **A4. 집과 연결된 각 거리의 지역은 그 지역의 다른 집과 비슷한 지역 일 가능성이 높기 때문에 data를 그룹화 해줍니다. Q4의 경우, data 내 NaN을 각 그룹에서 파생된 mean 값으로 치환했습니다.**
#
#
#
#
# https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html

# %% [markdown]
# - **Q5. GarageType, GarageFinish, GarageQual and GarageCond** : Replacing missing data with None

# %%
for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    all_data[col] = all_data[col].fillna('None')

# %% [markdown]
# **A5. fillna를 이용해 결측치를 None으로 치환하였습니다.**

# %% [markdown]
# - **Q6. GarageYrBlt, GarageArea and GarageCars** : Replacing missing data with 0 (Since No garage = no cars in such garage.)

# %%
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
    all_data[col] = all_data[col].fillna(0)

# %% [markdown]
# **A5. fillna를 이용해 결측치를 0로 치환하였습니다.**

# %% [markdown]
# - **Q7. BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, BsmtFullBath and BsmtHalfBath** : missing values are likely zero for having no basement

# %%
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    all_data[col] = all_data[col].fillna(0)

# %% [markdown]
# - **Q8. BsmtQual, BsmtCond, BsmtExposure, BsmtFinType1 and BsmtFinType2** : For all these categorical basement-related features, NaN means that there is no  basement.

# %%
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    all_data[col] = all_data[col].fillna(0)

# %% [markdown]
# - **Q9. MasVnrArea and MasVnrType** : NA most likely means no masonry veneer for these houses. We can fill 0 for the area and None for the type.

# %%
all_data["MasVnrType"] = all_data["MasVnrType"].fillna("None")
all_data["MasVnrArea"] = all_data["MasVnrArea"].fillna(0)

# %% [markdown]
# - **MSZoning (The general zoning classification)** :  'RL' is by far  the most common value.  So we can fill in missing values with 'RL'
#
# **Q10. MSZoning에서 가장 많이 존재하는 값으로 결측치를 대체하세요**

# %%
all_data['MSZoning'].value_counts()
# Out:
# RL         1150
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %% [markdown]
# RL이 최빈값입니다.

# %%
#최빈값만 return
all_data['MSZoning'].value_counts(dropna=True).idxmax()
# Out:
# 'RL'

# %%
all_data.index[all_data['MSZoning'].isnull()]
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# ???결측치가 없낭?? 우선 최빈값으로 대치하장

# %%
most_freq = all_data['MSZoning'].value_counts(dropna=True).idxmax()

all_data['MSZoning'].fillna(most_freq, inplace = True)

# %% [markdown]
# **A10. 최빈값을 return하는 함수(value_counts(dropna=True).idxmax())를 사용하여 결측치를 처리했습니다.**
#
# https://yganalyst.github.io/study/Pd_6/

# %% [markdown]
# - **Utilities** : For this categorical feature all records are "AllPub", except for one "NoSeWa"  and 2 NA . Since the house with 'NoSewa' is in the training set, **this feature won't help in predictive modelling**. We can then safely  remove it.

# %%
all_data = all_data.drop(['Utilities'], axis=1)

# %% [markdown]
# - **Functional** : data description says NA means typical

# %%
all_data["Functional"] = all_data["Functional"].fillna("Typ")

# %% [markdown]
# - **Electrical** : It has one NA value. Since this feature has mostly 'SBrkr', we can set that for the missing value.

# %% [markdown]
# **Q11.  가장 많이 존재하는 값으로 결측치를 대체하세요**

# %%
all_data['Electrical'].fillna(all_data['Electrical'].value_counts(dropna=True).idxmax() , inplace = True)

# %% [markdown]
# - **KitchenQual**: Only one NA value, and same as Electrical, we set 'TA' (which is the most frequent)  for the missing value in KitchenQual.

# %%
all_data['KitchenQual'].fillna(all_data['KitchenQual'].value_counts(dropna=True).idxmax() , inplace = True)

# %% [markdown]
# - **Exterior1st and Exterior2nd** : Again Both Exterior 1 & 2 have only one missing value. We will just substitute in the most common string

# %%
all_data['Exterior1st'].fillna(all_data['Exterior1st'].value_counts(dropna=True).idxmax() , inplace = True)
all_data['Exterior2nd'].fillna(all_data['Exterior2nd'].value_counts(dropna=True).idxmax() , inplace = True)

# %% [markdown]
# - **SaleType** : Fill in again with most frequent which is "WD"

# %%
all_data['SaleType'].fillna(all_data['SaleType'].value_counts(dropna=True).idxmax() , inplace = True)

# %% [markdown]
# **A11. Q10과 동일하게 처리했습니다.**

# %% [markdown]
# - **MSSubClass** : Na most likely means No building class. We can replace missing values with None

# %%
all_data['MSSubClass'] = all_data['MSSubClass'].fillna("None")

# %% [markdown]
# Is there any remaining missing value ?

# %%
#Check remaining missing values if any 
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head()
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %% [markdown]
# 결측치 처리 성공쓰~

# %% [markdown]
# ### More features engeneering

# %% [markdown]
# **Transforming some numerical variables that are really categorical**
#
# 숫자형태를 한 값일 뿐 실제 연속형도 숫자 데이터도 아니죠? 따라서 문자형식으로 바꾼후 라벨링 인코더 하겠습니다.

# %% [markdown]
# **Q12. 데이터를 문자형으로 바꾸세요.**

# %%
all_data['MSSubClass'].dtypes
# Out:
# dtype('int64')

# %%
#MSSubClass=The building class
all_data['MSSubClass'] = all_data['MSSubClass'].astype('str')

# %%
all_data['MSSubClass'].dtypes
# Out:
# dtype('O')

# %%
type(all_data['MSSubClass'][0])
# Out:
# str

# %% [markdown]
# string으로 잘 변환되는것을 확인\
#
#
# dtype('0') :\
# Pandas dtype : object  \
# Python type : str\
# NumPy type :  string_, unicode_ \
# Usage : Text
#
#
# https://stackoverflow.com/questions/37561991/what-is-dtypeo

# %%
#Changing OverallCond into a categorical variable
all_data['OverallCond'] = all_data['OverallCond'].astype('str')


#Year and month sold are transformed into categorical features.
all_data['YrSold'] = all_data['YrSold'].astype('str')
all_data['MoSold'] = all_data['MoSold'].astype('str')

# %% [markdown]
# **A12. dtpye으로 series전체를 문자형으로 변환**

# %% [markdown]
# **Label Encoding some categorical variables that may contain information in their ordering set**

# %% [markdown]
# **Q13. LabelEncoder로 해당 범주형 데이터를 바꿔보세요..**

# %%
from sklearn.preprocessing import LabelEncoder
cols = ('FireplaceQu', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 
        'ExterQual', 'ExterCond','HeatingQC', 'PoolQC', 'KitchenQual', 'BsmtFinType1', 
        'BsmtFinType2', 'Functional', 'Fence', 'BsmtExposure', 'GarageFinish', 'LandSlope',
        'LotShape', 'PavedDrive', 'Street', 'Alley', 'CentralAir', 'MSSubClass', 'OverallCond', 
        'YrSold', 'MoSold')

for col in cols:
    lbl = LabelEncoder() 
    lbl.fit(list(all_data[col].values)) 
    all_data[col] = lbl.transform(list(all_data[col].values))


# shape        
print('Shape all_data: {}'.format(all_data.shape))
# Out:
# Shape all_data: (1459, 78)

# %% [markdown]
# **Adding one more important feature**

# %%
# Adding total sqfootage feature 
all_data['TotalSF'] = all_data['TotalBsmtSF'] + all_data['1stFlrSF'] + all_data['2ndFlrSF']

# %% [markdown]
# **Skewed features**

# %%
numeric_feats = all_data.dtypes[all_data.dtypes != "object"].index

skewed_feats = all_data[numeric_feats].apply(lambda x: skew(x.dropna())).sort_values(ascending=False)
print("\nSkew in numerical features: \n")
skewness = pd.DataFrame({'Skew' :skewed_feats})
skewness.head(10)
# Out:
# Skew in numerical features:
#                    Skew
# MiscVal       24.443278
# PoolArea      14.807992
# LotArea       12.290047
# 3SsnPorch     10.290132
# LowQualFinSF   8.998885
# LandSlope      4.806884
# KitchenAbvGr   4.482026
# BsmtFinSF2     4.249219
# ScreenPorch    4.116334
# BsmtHalfBath   4.097541

# %% [markdown]
# **Box Cox Transformation of (highly) skewed features**

# %% [markdown]
# We use the scipy  function boxcox1p which computes the Box-Cox transformation of **\\(1 + x\\)**.
#
# Note that setting \\( \lambda = 0 \\) is equivalent to log1p used above for the target variable.
#
# See [this page][1] for more details on Box Cox Transformation as well as [the scipy function's page][2]
# [1]: http://onlinestatbook.com/2/transformations/box-cox.html
# [2]: https://docs.scipy.org/doc/scipy-0.19.0/reference/generated/scipy.special.boxcox1p.html

# %%
skewness = skewness[abs(skewness) > 0.75]


from scipy.special import boxcox1p
skewed_features = skewness.index
lam = 0.15
for feat in skewed_features:
    all_data[feat] = boxcox1p(all_data[feat], lam)

# %% [markdown]
# **Getting dummy categorical features**

# %% [markdown]
# **Q14. 더미화하세요.**

# %%
all_data = pd.get_dummies(all_data)
print(all_data.shape)
# Out:
# (1459, 221)

# %% [markdown]
# **A14. get_dummies를 사용하여 one_hot encoding된 dummy변수로 변환

# %% [markdown]
# Getting the new train and test sets.

# %%
train = all_data[:ntrain]
test = all_data[ntrain:]

# %% [markdown]
# #Modelling

# %% [markdown]
# # <span style="color:blue"> 이 아래부터의 과정은 앙상블을 정말 모르겠다.(코드) 그런 분들을 위해 참조용으로 있을 뿐. 알아서 하셔도 무방합니다.

# %% [markdown]
# **Import librairies**

# %%
# ! pip install xgboost

# %%
# ! pip install lightgbm

# %%
from sklearn.linear_model import ElasticNet, Lasso,  BayesianRidge, LassoLarsIC
from sklearn.ensemble import RandomForestRegressor,  GradientBoostingRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import RobustScaler
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin, clone
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb

# %% [markdown]
# **Define a cross validation strategy**

# %% [markdown]
# We use the **cross_val_score** function of Sklearn. However this function has not a shuffle attribut, we add then one line of code,  in order to shuffle the dataset  prior to cross-validation

# %%
#Validation function
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
    rmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %% [markdown]
# ##Base models

# %% [markdown]
# -  **LASSO  Regression**  :
#
# This model may be very sensitive to outliers. So we need to made it more robust on them. For that we use the sklearn's  **Robustscaler()**  method on pipeline

# %%
lasso = make_pipeline(RobustScaler(), Lasso(alpha =0.0005, random_state=1))

# %% [markdown]
# - **Elastic Net Regression** :
#
# again made robust to outliers

# %%
ENet = make_pipeline(RobustScaler(), ElasticNet(alpha=0.0005, l1_ratio=.9, random_state=3))

# %% [markdown]
# - **Kernel Ridge Regression** :

# %%
KRR = KernelRidge(alpha=0.6, kernel='polynomial', degree=2, coef0=2.5)

# %% [markdown]
# - **Gradient Boosting Regression** :
#
# With **huber**  loss that makes it robust to outliers

# %%
GBoost = GradientBoostingRegressor(n_estimators=3000, learning_rate=0.05,
                                   max_depth=4, max_features='sqrt',
                                   min_samples_leaf=15, min_samples_split=10, 
                                   loss='huber', random_state =5)

# %% [markdown]
# - **XGBoost** :

# %%
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

# %% [markdown]
# - **LightGBM** :

# %%
model_lgb = lgb.LGBMRegressor(objective='regression',num_leaves=5,
                              learning_rate=0.05, n_estimators=720,
                              max_bin = 55, bagging_fraction = 0.8,
                              bagging_freq = 5, feature_fraction = 0.2319,
                              feature_fraction_seed=9, bagging_seed=9,
                              min_data_in_leaf =6, min_sum_hessian_in_leaf = 11)

# %% [markdown]
# ###Base models scores

# %% [markdown]
# cross-validation rmsle error로 모델 성능을 확인해 봅시다

# %%
score = rmsle_cv(lasso)
print("\nLasso score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Lasso score: 0.1171 (0.0123)

# %%
score = rmsle_cv(ENet)
print("ElasticNet score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# ElasticNet score: 0.1175 (0.0124)

# %%
score = rmsle_cv(KRR)
print("Kernel Ridge score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Kernel Ridge score: 0.1250 (0.0140)

# %%
score = rmsle_cv(GBoost)
print("Gradient Boosting score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Gradient Boosting score: 0.1262 (0.0119)

# %%
score = rmsle_cv(model_xgb)
print("Xgboost score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# Xgboost score: 0.1246 (0.0085)

# %%
score = rmsle_cv(model_lgb)
print("LGBM score: {:.4f} ({:.4f})\n" .format(score.mean(), score.std()))
# Out:
# LGBM score: 0.1225 (0.0120)

# %% [markdown]
# ##Stacking  models

# %% [markdown]
# ###Simplest Stacking approach : Averaging base models

# %% [markdown]
# **Averaged base models class**

# %%
class AveragingModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, models):
        self.models = models
        
    # we define clones of the original models to fit the data in
    def fit(self, X, y):
        self.models_ = [clone(x) for x in self.models]
        
        # Train cloned base models
        for model in self.models_:
            model.fit(X, y)

        return self
    
    #Now we do the predictions for cloned models and average them
    def predict(self, X):
        predictions = np.column_stack([
            model.predict(X) for model in self.models_
        ])
        return np.mean(predictions, axis=1)

# %% [markdown]
# **Averaged base models score**

# %%
averaged_models = AveragingModels(models = (ENet, GBoost, KRR, lasso))
score = rmsle_cv(averaged_models)
print(" Averaged base models score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
#  Averaged base models score: 0.1146 (0.0123)

# %% [markdown]
# ###Less simple Stacking : Adding a Meta-model

# %% [markdown]
# In this approach, we add a meta-model on averaged base models and use the out-of-folds predictions of these base models to train our meta-model.
#
# The procedure, for the training part, may be described as follows:
#
#
# 1. Split the total training set into two disjoint sets (here **train** and .**holdout** )
#
# 2. Train several base models on the first part (**train**)
#
# 3. Test these base models on the second part (**holdout**)
#
# 4. Use the predictions from 3)  (called  out-of-folds predictions) as the inputs, and the correct responses (target variable) as the outputs  to train a higher level learner called **meta-model**.
#
# The first three steps are done iteratively . If we take for example a 5-fold stacking , we first split the training data into 5 folds. Then we will do 5 iterations. In each iteration,  we train every base model on 4 folds and predict on the remaining fold (holdout fold).
#
# So, we will be sure, after 5 iterations , that the entire data is used to get out-of-folds predictions that we will then use as
# new feature to train our meta-model in the step 4.
#
# For the prediction part , We average the predictions of  all base models on the test data  and used them as **meta-features**  on which, the final prediction is done with the meta-model.

# %% [markdown]
# ![Faron](http://i.imgur.com/QBuDOjs.jpg)
#
# (Image taken from [Faron](https://www.kaggle.com/getting-started/18153#post103381))

# %% [markdown]
# On this gif, the base models are algorithms 0, 1, 2 and the meta-model is algorithm 3. The entire training dataset is
# A+B (target variable y known) that we can split into train part (A) and holdout part (B). And the test dataset is C.
#
# B1 (which is the prediction from the holdout part)  is the new feature used to train the meta-model 3 and C1 (which
# is the prediction  from the test dataset) is the meta-feature on which the final prediction is done.

# %% [markdown]
# **Stacking averaged Models Class**

# %%
class StackingAveragedModels(BaseEstimator, RegressorMixin, TransformerMixin):
    def __init__(self, base_models, meta_model, n_folds=5):
        self.base_models = base_models
        self.meta_model = meta_model
        self.n_folds = n_folds
   
    # We again fit the data on clones of the original models
    def fit(self, X, y):
        self.base_models_ = [list() for x in self.base_models]
        self.meta_model_ = clone(self.meta_model)
        kfold = KFold(n_splits=self.n_folds, shuffle=True, random_state=156)
        
        # Train cloned base models then create out-of-fold predictions
        # that are needed to train the cloned meta-model
        out_of_fold_predictions = np.zeros((X.shape[0], len(self.base_models)))
        for i, model in enumerate(self.base_models):
            for train_index, holdout_index in kfold.split(X, y):
                instance = clone(model)
                self.base_models_[i].append(instance)
                instance.fit(X[train_index], y[train_index])
                y_pred = instance.predict(X[holdout_index])
                out_of_fold_predictions[holdout_index, i] = y_pred
                
        # Now train the cloned  meta-model using the out-of-fold predictions as new feature
        self.meta_model_.fit(out_of_fold_predictions, y)
        return self
   
    #Do the predictions of all base models on the test data and use the averaged predictions as 
    #meta-features for the final prediction which is done by the meta-model 
    def predict(self, X):
        meta_features = np.column_stack([
            np.column_stack([model.predict(X) for model in base_models]).mean(axis=1)
            for base_models in self.base_models_ ])
        return self.meta_model_.predict(meta_features)

# %% [markdown]
# **Stacking Averaged models Score**

# %%
stacked_averaged_models_l = StackingAveragedModels(base_models = (ENet, GBoost, KRR),
                                                 meta_model = lasso)


score = rmsle_cv(stacked_averaged_models_l)                 
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# Stacking Averaged models score: 0.1128 (0.0127)

# %%
stacked_averaged_models_E = StackingAveragedModels(base_models = (lasso, GBoost, KRR),
                                                 meta_model = ENet)


score = rmsle_cv(stacked_averaged_models_E)                 
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# Stacking Averaged models score: 0.1128 (0.0127)

# %%
stacked_averaged_models_G = StackingAveragedModels(base_models = (ENet, lasso, KRR),
                                                 meta_model = GBoost)


score = rmsle_cv(stacked_averaged_models_G)                 
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# Stacking Averaged models score: 0.1290 (0.0171)

# %%
stacked_averaged_models_K = StackingAveragedModels(base_models = (ENet, GBoost, lasso),
                                                 meta_model = KRR)


score = rmsle_cv(stacked_averaged_models_K)                 
print("Stacking Averaged models score: {:.4f} ({:.4f})".format(score.mean(), score.std()))
# Out:
# Stacking Averaged models score: 0.1126 (0.0125)

# %% [markdown]
# **score가 가장 낮은
# base_models = (ENet, GBoost, KRR),meta_model = lasso 선택**

# %%
def rmsle(y, y_pred):
    return np.sqrt(mean_squared_error(y, y_pred))

# %% [markdown]
# ### Final Training and Prediction

# %% [markdown]
# **StackedRegressor:**

# %% [markdown]
# #같은 방식으로 여러 모델을 학습하고 예측값을 뺴보세요.

# %%
stacked_averaged_models_l.fit(train.values, y_train)
stacked_train_pred = stacked_averaged_models_l.predict(train.values)
stacked_pred = stacked_averaged_models_l.predict(test.values)
print(rmsle(y_train, stacked_train_pred))
# Out:
# 0.0724130536281536

# %%
lasso.fit(train, y_train)
lasso_train_pred = lasso.predict(train)
lasso_pred = lasso.predict(test)
print(rmsle(y_train, lasso_train_pred))
# Out:
# 0.09903577722644424

# %%
ENet.fit(train, y_train)
EN_train_pred = ENet.predict(train)
EN_pred = ENet.predict(test)
print(rmsle(y_train, EN_train_pred))
# Out:
# 0.0982620594465728

# %%
KRR.fit(train, y_train)
KRR_train_pred = KRR.predict(train)
KRR_pred = KRR.predict(test)
print(rmsle(y_train, KRR_train_pred))
# Out:
# 0.08092327032291538

# %%
model_xgb.fit(train, y_train)
xgb_train_pred = model_xgb.predict(train)
# xgb_pred = np.expm1(model_xgb.predict(test))
xgb_pred = model_xgb.predict(test)
print(rmsle(y_train, xgb_train_pred))
# Out:
# 0.08007218728783401

# %%
model_lgb.fit(train, y_train)
lgb_train_pred = model_lgb.predict(train)
lgb_pred = model_lgb.predict(test.values)
print(rmsle(y_train, lgb_train_pred))
# Out:
# 0.061940192068503146

# %%
GBoost.fit(train, y_train)
GBoost_train_pred = GBoost.predict(train)
GBoost_pred = GBoost.predict(test.values)
print(rmsle(y_train, GBoost_train_pred))
# Out:
# 0.048980281442959586

# %% [markdown]
# rmse가 낮은 순서 :
# 1. GBoost
# 2. model_lgb
# 3. stacked_train_pred
#
# 이 세가지 model들의 조함으로 mse값이 가장 작은 parameter를 선택한다.

# %%
rmse_list = []
idx_i = []
idx_j = []
idx_k = []

def myrange(start, end, step):
    r = start
    while(r<end):
        yield r
        r += step

        

for i in myrange(0, 1, 0.01):
    for j in myrange(0, 1 - i, 0.01):
        k = 1 - i -j
        rmse_list.append(rmsle(y_train,stacked_train_pred*i + xgb_train_pred*j + lgb_train_pred*k))
        idx_i.append(i)
        idx_j.append(j)
        idx_k.append(k)

# %%
dic = {'rmse' : rmse_list, 'i' : idx_i, 'j' : idx_j, 'k' : idx_k}
df_idx =pd.DataFrame(dic)
df_idx
# Out:
#           rmse     i     j     k
# 0     0.061940  0.00  0.00  1.00
# 1     0.062038  0.00  0.01  0.99
# 2     0.062138  0.00  0.02  0.98
# 3     0.062240  0.00  0.03  0.97
# 4     0.062345  0.00  0.04  0.96
# ...        ...   ...   ...   ...
# 5045  0.072014  0.97  0.01  0.02
# 5046  0.072165  0.97  0.02  0.01
# 5047  0.072047  0.98  0.00  0.02
# 5048  0.072196  0.98  0.01  0.01
# 5049  0.072229  0.99  0.00  0.01
#
# [5050 rows x 4 columns]

# %%
df_idx['rmse'].min()
# Out:
# 0.061940192068503146

# %%
df_idx.index[df_idx['rmse'] == 0.048436886206649106 ]
# Out:
# Int64Index([], dtype='int64')

# %%
df_idx.loc[4913]
# Out:
# rmse    0.071976
# i       0.830000
# j       0.160000
# k       0.010000
# Name: 4913, dtype: float64

# %% [markdown]
# 최소의 rmse는 0.4633이고, 그때의 weight 비율은\
#
# **GBoost_train_pred x 0.83\
# lgb_train_pred x 0.16\
# stacked_train_pred x 0.01**
# 이다

# %%
print('RMSLE score on train data:')
print(rmsle(y_train,GBoost_train_pred*0.83 +
               stacked_train_pred*0.01 + lgb_train_pred*0.16 ))
# Out:
# RMSLE score on train data:
# 0.04843688620664907

# %% [markdown]
# **rmse가 최소인 두개의 model로 해보자**

# %%
rmse_list = []
idx_i = []
idx_j = []

def myrange(start, end, step):
    r = start
    while(r<end):
        yield r
        r += step

        

for i in myrange(0, 1, 0.01):
    j = 1 - i
    rmse_list.append(rmsle(y_train,GBoost_train_pred*i + lgb_train_pred*j))
    idx_i.append(i)
    idx_j.append(j)

# %%
dic = {'rmse' : rmse_list, 'i' : idx_i, 'j' : idx_j}
df_idx =pd.DataFrame(dic)
df_idx
# Out:
#         rmse     i     j
# 0   0.061940  0.00  1.00
# 1   0.061649  0.01  0.99
# 2   0.061359  0.02  0.98
# 3   0.061072  0.03  0.97
# 4   0.060787  0.04  0.96
# ..       ...   ...   ...
# 95  0.048653  0.95  0.05
# 96  0.048709  0.96  0.04
# 97  0.048770  0.97  0.03
# 98  0.048836  0.98  0.02
# 99  0.048906  0.99  0.01
#
# [100 rows x 3 columns]

# %%
df_idx['rmse'].min()
# Out:
# 0.048320739496795044

# %% [markdown]
# 3개의 model로 했을 때 보다 rmse가 아주 조금 낮다

# %%
df_idx.index[df_idx['rmse'] == 0.048320739496795044 ]
# Out:
# Int64Index([83], dtype='int64')

# %%
df_idx.loc[83]
# Out:
# rmse    0.048321
# i       0.830000
# j       0.170000
# Name: 83, dtype: float64

# %% [markdown]
# stacked_averaged_model이 포함되지 않는다.

# %% [markdown]
# **rmse가 최소인 네개의 model로 해보자**

# %%
model_xgb

rmse_list = []
idx_i = []
idx_j = []
idx_k = []

def myrange(start, end, step):
    r = start
    while(r<end):
        yield r
        r += step

        

for i in myrange(0, 1, 0.01):
    for j in myrange(0, 1-i, 0.01):
        for k in myrange(0, 1-i-j, 0.01):
            l = 1 - i - j - k
       
            rmse_list.append(rmsle(y_train,GBoost_train_pred*i + lgb_train_pred*j + stacked_train_pred*k + xgb_train_pred*l))
            idx_i.append(i)
            idx_j.append(j)
            idx_k.append(k)

# %%
dic = {'rmse' : rmse_list, 'i' : idx_i, 'j' : idx_j, 'k' : idx_k}
df_idx =pd.DataFrame(dic)
df_idx
# Out:
#             rmse     i     j     k
# 0       0.080072  0.00  0.00  0.00
# 1       0.079895  0.00  0.00  0.01
# 2       0.079720  0.00  0.00  0.02
# 3       0.079546  0.00  0.00  0.03
# 4       0.079374  0.00  0.00  0.04
# ...          ...   ...   ...   ...
# 171695  0.048845  0.97  0.02  0.00
# 171696  0.048987  0.98  0.00  0.00
# 171697  0.049044  0.98  0.00  0.01
# 171698  0.048910  0.98  0.01  0.00
# 171699  0.048980  0.99  0.00  0.00
#
# [171700 rows x 4 columns]

# %%
df_idx['rmse'].min()
# Out:
# 0.04840357930082236

# %% [markdown]
# 두개의 model로 앙상블 하였을때가 가장 낮은 score였지만 stacking model이 안들어가있기 때문에 차이가 많이 없는 3개 model조합으로 하였다.

# %% [markdown]
# **Ensemble prediction:**
# GBoost_train_pred x 0.83
# lgb_train_pred x 0.16
# stacked_train_pred x 0.01
# 사용

# %%
ensemble =  stacked_pred*0.83 + xgb_pred*0.16+ lgb_pred*0.01
# 앙상블 결과 저장

# %%
ensemble
# Out:
# array([12.02765015, 11.77694103, 11.89592668, 11.88219443, 12.24601123,
#        11.79626611, 12.46294686, 11.77518242, 12.07731349, 12.36550123,
#        11.51223767, 12.12992577, 11.65920437, 11.79690918, 11.45453833,
#        12.70436925, 11.86480371, 12.70466911, 11.92371946, 11.81176153,
#        11.94301193, 12.29316435, 12.0526508 , 11.77215766, 11.65377926,
#        12.42952145, 12.00186087, 11.84132291, 12.58627693, 11.97025025,
#        11.66842855, 12.04560427, 11.87770494, 11.95699283, 11.71273132,
#        12.01215254, 11.50333561, 11.86982359, 13.07269614, 11.8445689 ,
#        11.61927175, 11.91038735, 12.11630209, 12.43373133, 11.66626232,
#        11.73516052, 12.49390269, 12.33906644, 11.79275036, 12.07424955,
#        11.94312557, 11.93348238, 11.48760183, 11.96671661, 12.01678331,
#        11.40354321, 10.79668456, 11.80712693, 12.43681392, 12.1319725 ,
#        12.171493  , 11.98996577, 12.0940123 , 12.19776005, 12.24357823,
#        11.93219657, 12.64394239, 12.12516222, 12.45619873, 12.30478961,
#        12.29775719, 11.7583002 , 12.67428702, 12.20790571, 12.36088301,
#        11.43891249, 12.14606691, 12.40016423, 12.40490711, 12.30021356,
#        12.06034248, 12.3495595 , 11.67168954, 11.88654963, 11.92007832,
#        11.98174849, 11.89527844, 12.52551548, 12.27319843, 12.06686898,
#        11.84701365, 11.651606  , 11.75040987, 12.00636277, 11.67423671,
#        11.98514011, 11.74729689, 11.7501026 , 12.17521789, 12.01260538,
#        11.6896778 , 12.49856667, 11.98491505, 12.53721317, 12.32522509,
#        12.0777924 , 11.86516875, 11.80075786, 11.20311407, 11.74158998,
#        11.3737634 , 12.06651725, 11.6920678 , 12.24599909, 12.13182766,
#        12.02904749, 11.35467262, 12.1730474 , 11.53484544, 11.82154723,
#        12.14583569, 12.67957279, 12.06979358, 12.38934045, 11.81584624,
#        11.7245648 , 11.76419338, 12.8885859 , 12.13324183, 12.18454318,
#        12.6454665 , 12.15073749, 12.22220637, 12.05146667, 12.73480557,
#        11.62884421, 11.75035398, 11.95341675, 11.41859551, 12.16030844,
#        11.13469812, 11.2578024 , 12.40767863, 11.90415095, 12.16991717,
#        11.82081671, 12.01140447, 11.43460476, 12.43904766, 11.61470058,
#        11.73774784, 11.64690354, 11.98975006, 11.47485551, 11.74943   ,
#        12.22458167, 12.30634575, 12.13867726, 12.0362452 , 12.18557443,
#        11.95135996, 12.21320438, 11.6718345 , 12.16909403, 12.61753024,
#        11.6923402 , 11.87269828, 12.59983674, 11.72369383, 11.69808293,
#        11.84163621, 12.3026168 , 12.65519012, 12.35448372, 11.73570731,
#        11.20578485, 12.62930913, 12.46067908, 11.51090872, 11.25157256,
#        11.94583337, 12.02391304, 12.20152868, 12.48431099, 12.65620613,
#        11.79988586, 13.04643802, 11.86076479, 11.87174963, 11.4993894 ,
#        12.13299196, 12.16718178, 12.06817848, 11.8925401 , 12.4726257 ,
#        11.98021305, 12.28970878, 12.44028757, 12.76301455, 12.17906806,
#        12.22342884, 11.37298513, 11.79267742, 11.80268021, 11.92982004,
#        12.50072768, 12.06516509, 12.07024154, 12.07825757, 11.78087225,
#        11.78823396, 11.93859992, 11.52897642, 11.86514811, 12.14591478,
#        12.13747593, 11.99482656, 11.78937334, 11.85859567, 11.80057364,
#        11.96875367, 11.74396936, 12.17155216, 11.93943524, 12.09492001,
#        11.95754224, 11.48436025, 12.47849853, 11.83597404, 12.20668816,
#        11.41243016, 11.96195791, 12.04196809, 11.96731595, 11.77541654,
#        12.06001494, 11.70260724, 11.97511284, 11.62728233, 11.97098999,
#        10.9787123 , 11.6876878 , 11.7763056 , 11.94701908, 11.61406317,
#        12.69536129, 12.14987845, 12.44644837, 12.01996581, 12.62579517,
#        12.10579749, 12.17874565, 11.65658926, 11.80648616, 11.68150229,
#        12.66665401, 12.16931419, 11.81412754, 11.82148056, 11.76337695,
#        11.62531296, 12.31557352, 11.28279795, 11.44262582, 12.03067627,
#        11.63203903, 12.23976557, 12.39308026, 12.30591521, 11.76738075,
#        11.88116386, 11.64834408, 11.79889413, 12.3600841 , 12.08563925,
#        11.54825026, 11.70258812, 11.45678666, 12.23071582, 11.6916817 ,
#        11.70474878, 12.1207924 , 12.8799764 , 11.48171913, 11.41766101,
#        11.79607793, 12.0899629 , 12.09063652, 11.63815615, 11.97531783,
#        11.70026941, 11.95570819, 12.25338557, 11.71289582, 12.29931497,
#        12.22005119, 12.09513656, 12.25491672, 12.38677094, 12.13789424,
#        11.88513934, 12.28842659, 11.76051451, 11.79934754, 12.20891698,
#        12.31660879, 12.42748818, 12.17445547, 12.21279852, 13.14547063,
#        11.90217137, 11.98381548, 11.99541985, 12.35020762, 12.30938407,
#        12.68993998, 11.73002713, 11.62957141, 11.76667719, 11.38617651,
#        12.42959414, 12.53884966, 13.10909511, 11.90552419, 12.24912508,
#        11.714797  , 11.68986555, 12.5407488 , 12.12961571, 12.17162946,
#        12.16024434, 12.04515398, 11.80565788, 11.98432715, 11.87667039,
#        12.01043714, 12.36637578, 11.89779275, 12.06210642, 11.85841853,
#        11.46570839, 12.18623575, 11.75716955, 12.22637585, 11.92223302,
#        12.57068636, 11.62180039, 12.29118885, 11.86672475, 12.56790644,
#        12.16862022, 12.24697889, 11.32149363, 11.80498161, 11.77348135,
#        11.63514334, 11.80744422, 12.37639567, 11.19383855, 11.37843374,
#        11.56161888, 11.77544709, 11.98263392, 11.88871378, 12.22329905,
#        11.87131912, 12.36318002, 11.9015178 , 12.79083817, 11.86991283,
#        12.19176524, 11.89692047, 11.56384985, 11.78604963, 11.66848997,
#        11.84279597, 12.04396785, 12.28921205, 11.84885624, 12.37746814,
#        12.26942161, 12.44967772, 11.99589008, 12.96509692, 12.18035191,
#        12.17937916, 12.18155366, 11.85641228, 11.94732746, 11.70838163,
#        12.49304302, 12.14780655, 11.65662816, 12.49182249, 12.118278  ,
#        11.80193419, 12.68358865, 11.41786822, 12.12490786, 11.95196567,
#        12.1890429 , 11.7362389 , 11.8556704 , 11.98726043, 11.96956566,
#        12.07270171, 11.72880749, 12.76229886, 12.82485497, 11.84572381,
#        12.3852328 , 12.04075513, 11.7935229 , 12.0799772 , 11.83190326,
#        11.87813546, 11.934349  , 12.19117361, 12.42092048, 11.25059834,
#        12.25769084, 12.16772617, 11.89785062, 11.86653627, 12.14137467,
#        11.73244563, 11.9349072 , 12.11196677, 12.44594705, 12.57632352,
#        11.98336816, 11.66985743, 11.74731176, 12.12086533, 11.63275193,
#        11.8026964 , 11.91988056, 11.8277738 , 13.43530575, 12.04646032,
#        12.33561202, 11.9347146 , 12.64793987, 12.35535355, 11.87366557,
#        12.68404789, 12.22121147, 11.87181312, 11.90302138, 12.07263095,
#        12.65431751, 12.21621346, 12.68708546, 12.69087418, 11.61556316,
#        12.14483207, 12.50103116, 12.1661574 , 12.51737106, 11.59346891,
#        11.97240833, 11.24643758, 12.34236682, 11.32992335, 12.58959405,
#        11.08626597, 11.34255665, 11.78693905, 12.38321355, 12.13559174,
#        12.45394957, 11.80137839, 11.58371189, 11.76434997, 11.65808306,
#        11.98279989, 11.83868188, 10.97703179, 12.3478916 , 11.71800646,
#        11.58197945, 11.99296811, 12.39548816, 12.07489469, 12.11962654,
#        11.5046903 , 12.49445182, 12.59110386, 12.4091193 , 11.91011001,
#        12.15990796, 12.04587167, 11.74482107, 12.89212189, 12.36468979,
#        12.1575864 , 11.63183095, 11.96503661, 12.01729359, 12.84636311,
#        12.16604841, 12.5281681 , 11.74590463, 12.01903169, 11.85691447,
#        12.2404353 , 12.19299805, 11.83334008, 11.83548312, 12.4374478 ,
#        11.67463102, 12.13755752, 12.46015859, 13.00624155, 12.41924769,
#        12.42284977, 11.48625251, 11.82930078, 11.51307706, 11.9419494 ,
#        11.22927998, 12.33685959, 11.93949296, 11.96344009, 11.58587633,
#        11.63140083, 12.54226344, 11.99504505, 12.75699866, 11.80663932,
#        12.34526845, 11.80435389, 11.74724757, 11.93939481, 12.35272108,
#        12.57639578, 11.9933252 , 11.84035824, 11.82115692, 12.00523268,
#        11.68223638, 12.12981542, 12.16634668, 12.47361209, 11.49711565,
#        12.46479405, 11.76906679, 11.64573713, 11.67302759, 12.27174653,
#        12.31158803, 11.95430635, 11.48599951, 12.45728181, 12.13746973,
#        12.32419192, 11.80119899, 12.69092284, 11.78173324, 12.35506166,
#        12.03402163, 11.86082708, 11.82618672, 12.14540814, 11.86811544,
#        11.9192187 , 12.45549003, 11.86075062, 11.60973851, 12.17605351,
#        12.18039264, 11.76882177, 11.56557887, 12.15846423, 12.04102592,
#        12.01032576, 11.67403423, 12.86108099, 11.85531561, 12.09650996,
#        12.22105052, 11.8536749 , 12.76440233, 11.59369109, 12.18273278,
#        11.71650683, 11.90697943, 12.45799611, 11.62890033, 11.33780653,
#        11.83032843, 12.46567363, 11.75689759, 11.81214507, 12.15107613,
#        12.08741564, 12.19949391, 12.39995168, 11.82627741, 11.91511944])

# %% [markdown]
# **Submission**

# %%
sub = pd.DataFrame()
sub['Id'] = test_ID
sub['SalePrice'] = ensemble
sub.to_csv('submission.csv',index=False)

# %%
sub.head()
# Out:
#     Id  SalePrice
# 0  861  12.027650
# 1  862  11.776941
# 2  863  11.895927
# 3  864  11.882194
# 4  865  12.246011
